# %% [markdown]
# <b>Import Wikipedia page and transform it in Dataframe</b>

# %%
import pandas as pd
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M',index_col=1)
df = tables[0]

# %% [markdown]
# <b>Rename Collumns names</b>

# %%
df1=df.reset_index().rename(columns={"Postcode": "PostalCode", "Neighbourhood": "Neighborhood"})

# %% [markdown]
# <b>Remove rows where Borough cell is Not Assigned</b>

# %%
df2=df1[df1.Borough != "Not assigned"]

# %% [markdown]
# <b>Group neighborhoods with the same Borough and PostalCode</b>

# %%
df3=df2.groupby(['Borough','PostalCode'])['Neighborhood'].apply(','.join).reset_index()
df3
# Out:
#               Borough PostalCode  \
# 0     Central Toronto        M4N
# 1     Central Toronto        M4P
# 2     Central Toronto        M4R
# 3     Central Toronto        M4S
# 4     Central Toronto        M4T
# 5     Central Toronto        M4V
# 6     Central Toronto        M5N
# 7     Central Toronto        M5P
# 8     Central Toronto        M5R
# 9    Downtown Toronto        M4W
# 10   Downtown Toronto        M4X
# 11   Downtown Toronto        M4Y
# 12   Downtown Toronto        M5A
# 13   Downtown Toronto        M5B
# 14   Downtown Toronto        M5C
# 15   Downtown Toronto        M5E
# 16   Downtown Toronto        M5G
# 17   Downtown Toronto        M5H
# 18   Downtown Toronto        M5J
# 19   Downtown Toronto        M5K
# 20   Downtown Toronto        M5L
# 21   Downtown Toronto        M5S
# 22   Downtown Toronto        M5T
# 23   Downtown Toronto        M5V
# 24   Downtown Toronto        M5W
# 25   Downtown Toronto        M5X
# 26   Downtown Toronto        M6G
# 27       East Toronto        M4E
# 28       East Toronto        M4K
# 29       East Toronto        M4L
# ..                ...        ...
# 73         North York        M9M
# 74       Queen's Park        M7A
# 75        Scarborough        M1B
# 76        Scarborough        M1C
# 77        Scarborough        M1E
# 78        Scarborough        M1G
# 79        Scarborough        M1H
# 80        Scarborough        M1J
# 81        Scarborough        M1K
# 82        Scarborough        M1L
# 83        Scarborough        M1M
# 84        Scarborough        M1N
# 85        Scarborough        M1P
# 86        Scarborough        M1R
# 87        Scarborough        M1S
# 88        Scarborough        M1T
# 89        Scarborough        M1V
# 90        Scarborough        M1W
# 91        Scarborough        M1X
# 92       West Toronto        M6H
# 93       West Toronto        M6J
# 94       West Toronto        M6K
# 95       West Toronto        M6P
# 96       West Toronto        M6R
# 97       West Toronto        M6S
# 98               York        M6C
# 99               York        M6E
# 100              York        M6M
# 101              York        M6N
# 102              York        M9N
#
#                                           Neighborhood
# 0                                        Lawrence Park
# 1                                     Davisville North
# 2                                   North Toronto West
# 3                                           Davisville
# 4                           Moore Park,Summerhill East
# 5    Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 6                                             Roselawn
# 7                   Forest Hill North,Forest Hill West
# 8                    The Annex,North Midtown,Yorkville
# 9                                             Rosedale
# 10                          Cabbagetown,St. James Town
# 11                                Church and Wellesley
# 12                            Harbourfront,Regent Park
# 13                             Ryerson,Garden District
# 14                                      St. James Town
# 15                                         Berczy Park
# 16                                  Central Bay Street
# 17                              Adelaide,King,Richmond
# 18     Harbourfront East,Toronto Islands,Union Station
# 19             Design Exchange,Toronto Dominion Centre
# 20                       Commerce Court,Victoria Hotel
# 21                       Harbord,University of Toronto
# 22             Chinatown,Grange Park,Kensington Market
# 23   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 24                     Stn A PO Boxes 25 The Esplanade
# 25               First Canadian Place,Underground city
# 26                                            Christie
# 27                                         The Beaches
# 28                         The Danforth West,Riverdale
# 29                       The Beaches West,India Bazaar
# ..                                                 ...
# 73                                     Emery,Humberlea
# 74                                        Not assigned
# 75                                       Rouge,Malvern
# 76                Highland Creek,Rouge Hill,Port Union
# 77                     Guildwood,Morningside,West Hill
# 78                                              Woburn
# 79                                           Cedarbrae
# 80                                 Scarborough Village
# 81           East Birchmount Park,Ionview,Kennedy Park
# 82                       Clairlea,Golden Mile,Oakridge
# 83       Cliffcrest,Cliffside,Scarborough Village West
# 84                          Birch Cliff,Cliffside West
# 85   Dorset Park,Scarborough Town Centre,Wexford He...
# 86                                    Maryvale,Wexford
# 87                                           Agincourt
# 88               Clarks Corners,Sullivan,Tam O'Shanter
# 89   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 90                                     L'Amoreaux West
# 91                                         Upper Rouge
# 92                         Dovercourt Village,Dufferin
# 93                             Little Portugal,Trinity
# 94          Brockton,Exhibition Place,Parkdale Village
# 95                        High Park,The Junction South
# 96                               Parkdale,Roncesvalles
# 97                                   Runnymede,Swansea
# 98                                  Humewood-Cedarvale
# 99                                 Caledonia-Fairbanks
# 100        Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 101                       The Junction North,Runnymede
# 102                                             Weston
#
# [103 rows x 3 columns]

# %% [markdown]
# <b>Replace cells where Neighborhood value is set Not Assigned to Neighborhoods name</b>

# %%
import numpy as np
df3['Neighborhood'] = np.where(df3['Neighborhood'] == 'Not assigned', df3['Borough'], df3['Neighborhood'])
df3
# Out:
#               Borough PostalCode  \
# 0     Central Toronto        M4N
# 1     Central Toronto        M4P
# 2     Central Toronto        M4R
# 3     Central Toronto        M4S
# 4     Central Toronto        M4T
# 5     Central Toronto        M4V
# 6     Central Toronto        M5N
# 7     Central Toronto        M5P
# 8     Central Toronto        M5R
# 9    Downtown Toronto        M4W
# 10   Downtown Toronto        M4X
# 11   Downtown Toronto        M4Y
# 12   Downtown Toronto        M5A
# 13   Downtown Toronto        M5B
# 14   Downtown Toronto        M5C
# 15   Downtown Toronto        M5E
# 16   Downtown Toronto        M5G
# 17   Downtown Toronto        M5H
# 18   Downtown Toronto        M5J
# 19   Downtown Toronto        M5K
# 20   Downtown Toronto        M5L
# 21   Downtown Toronto        M5S
# 22   Downtown Toronto        M5T
# 23   Downtown Toronto        M5V
# 24   Downtown Toronto        M5W
# 25   Downtown Toronto        M5X
# 26   Downtown Toronto        M6G
# 27       East Toronto        M4E
# 28       East Toronto        M4K
# 29       East Toronto        M4L
# ..                ...        ...
# 73         North York        M9M
# 74       Queen's Park        M7A
# 75        Scarborough        M1B
# 76        Scarborough        M1C
# 77        Scarborough        M1E
# 78        Scarborough        M1G
# 79        Scarborough        M1H
# 80        Scarborough        M1J
# 81        Scarborough        M1K
# 82        Scarborough        M1L
# 83        Scarborough        M1M
# 84        Scarborough        M1N
# 85        Scarborough        M1P
# 86        Scarborough        M1R
# 87        Scarborough        M1S
# 88        Scarborough        M1T
# 89        Scarborough        M1V
# 90        Scarborough        M1W
# 91        Scarborough        M1X
# 92       West Toronto        M6H
# 93       West Toronto        M6J
# 94       West Toronto        M6K
# 95       West Toronto        M6P
# 96       West Toronto        M6R
# 97       West Toronto        M6S
# 98               York        M6C
# 99               York        M6E
# 100              York        M6M
# 101              York        M6N
# 102              York        M9N
#
#                                           Neighborhood
# 0                                        Lawrence Park
# 1                                     Davisville North
# 2                                   North Toronto West
# 3                                           Davisville
# 4                           Moore Park,Summerhill East
# 5    Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 6                                             Roselawn
# 7                   Forest Hill North,Forest Hill West
# 8                    The Annex,North Midtown,Yorkville
# 9                                             Rosedale
# 10                          Cabbagetown,St. James Town
# 11                                Church and Wellesley
# 12                            Harbourfront,Regent Park
# 13                             Ryerson,Garden District
# 14                                      St. James Town
# 15                                         Berczy Park
# 16                                  Central Bay Street
# 17                              Adelaide,King,Richmond
# 18     Harbourfront East,Toronto Islands,Union Station
# 19             Design Exchange,Toronto Dominion Centre
# 20                       Commerce Court,Victoria Hotel
# 21                       Harbord,University of Toronto
# 22             Chinatown,Grange Park,Kensington Market
# 23   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 24                     Stn A PO Boxes 25 The Esplanade
# 25               First Canadian Place,Underground city
# 26                                            Christie
# 27                                         The Beaches
# 28                         The Danforth West,Riverdale
# 29                       The Beaches West,India Bazaar
# ..                                                 ...
# 73                                     Emery,Humberlea
# 74                                        Queen's Park
# 75                                       Rouge,Malvern
# 76                Highland Creek,Rouge Hill,Port Union
# 77                     Guildwood,Morningside,West Hill
# 78                                              Woburn
# 79                                           Cedarbrae
# 80                                 Scarborough Village
# 81           East Birchmount Park,Ionview,Kennedy Park
# 82                       Clairlea,Golden Mile,Oakridge
# 83       Cliffcrest,Cliffside,Scarborough Village West
# 84                          Birch Cliff,Cliffside West
# 85   Dorset Park,Scarborough Town Centre,Wexford He...
# 86                                    Maryvale,Wexford
# 87                                           Agincourt
# 88               Clarks Corners,Sullivan,Tam O'Shanter
# 89   Agincourt North,L'Amoreaux East,Milliken,Steel...
# 90                                     L'Amoreaux West
# 91                                         Upper Rouge
# 92                         Dovercourt Village,Dufferin
# 93                             Little Portugal,Trinity
# 94          Brockton,Exhibition Place,Parkdale Village
# 95                        High Park,The Junction South
# 96                               Parkdale,Roncesvalles
# 97                                   Runnymede,Swansea
# 98                                  Humewood-Cedarvale
# 99                                 Caledonia-Fairbanks
# 100        Del Ray,Keelesdale,Mount Dennis,Silverthorn
# 101                       The Junction North,Runnymede
# 102                                             Weston
#
# [103 rows x 3 columns]

# %% [markdown]
# <b>Number of rows in dataframe</b>

# %%
df3.shape
# Out:
# (103, 3)
